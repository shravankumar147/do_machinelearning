# %% [markdown]
# ## Problem 1: Perceptron Learning
#
# ### 1.Use the data given in Table 1. Starting with w = [0 0] T and b = 0,apply your program to learn a linear classifier to separate classes C 1 and C 2 . Plot the data points for C 1 and C 2 . Plot the final classifier learnt at the convergence. Note the number of iterations required for convergence.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![alt text](perceptron.png "Title")

# %%
def percp(train, weights, nb_epoch=1):
    w = weights
    X = train
    for epoc in range(nb_epoch):
        print("*************************")
        print("Epoch {}".format(epoc))
        print("*************************")
        print(" ")
        print("current weights {}".format(w))
        print(" ")
        for i in range(len(X)):
            print("iteration{} on X{}".format(i,i))
            y = np.dot(X[i],w)
            count = 0
            if y<=0:
                print("xxxxxxx")
                print("Misclassified sample x{}".format(i))
                print("-------")
                w = w+X[i]
                print("-------")
                print("updated weight w = {}".format(w))
                print(":) :) :) ")
#                 count +=1
#                 print("inside {}".format(count))
#             print("outside {}".format(count))
        print(" ")           
        print("Finally the best weight vector is {} at iteration {}".format(w,epoc))
        print(" ")
    print(w)
    return w

# %%
def plot_classifier(x11,x21,x12,x22,w):
    c,a,b = w
    plt.figure(5)

    m = np.min([np.min(x11),np.min(x12),np.min(x21),np.min(x22)])
    M = np.max([np.max(x11),np.max(x12),np.max(x21),np.max(x22)])

    xx = np.linspace(m,M,100)
    yy = xx
#     yy = -1*(-8.9*xx + 15)/10.1
    yy = -1*(a*xx + c)/b
    plt.plot(xx,yy,'y')
    plt.hold(True)
    s=20
    plt.scatter(x11,x21,color='r', s=2*s, marker='^', alpha=.8, label='C1')
    plt.scatter(x12,x22,color='g', s=2*s, marker='o', alpha=.8, label='C2')
    plt.axis("tight")
    plt.legend(loc='upper left')
    plt.show()

# %%
x11 = np.array([[0.1],[6.8],[-3.5],[2],[4.1],[3.1],[-0.8],[0.9],[5],[3.9]])
x21 = np.array([[1.1],[7.1],[-4.1],[2.7],[2.8],[5],[-1.3],[1.2],[6.4],[4]])

# %%
x12 = np.array([[7.1],[-1.4],[4.5],[6.3],[4.2],[1.4],[2.4],[2.5],[8.4],[4.1]])
x22 = np.array([[4.2],[-4.3],[0],[1.6],[1.9],[-3.2],[-4],[-6.1],[3.7],[-2.2]])

# %%
x13 = np.array([[-3],[0.5],[2.9],[-0.1],[-4],[-1.3],[-3.4],[-4.1],[-5.1],[1.9]])
x23 = np.array([[-2.9],[8.7],[2.1],[5.2],[2.2],[3.7],[6.2],[3.4],[1.6],[5.1]])

# %% [markdown]
# Plot the data points for C 1 and C 2

# %%
plt.figure(1)
s=20
plt.scatter(x11,x21,color='r', s=2*s, marker='^', alpha=.8, label='C1')
plt.scatter(x12,x22,color='g', s=2*s, marker='o', alpha=.8, label='C2')
plt.title("Class1 vs. Class2")
plt.xlabel("x1")
plt.ylabel("x2")
plt.axis("tight")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Plot the final classifier learnt at
# the convergence. Note the number of iterations required for convergence.

# %%
X1 = np.c_[np.ones(x11.shape), x11, x21]
X2 = np.c_[np.ones(x12.shape), x12, x22]
X12 = np.r_[X1,-X2]
w = np.array([0,0,0])

# %%
w1 = percp(X12,w.T,20)
# Out:
# *************************
# Epoch 0
# *************************
#
# current weights [0 0 0]
#
# iteration0 on X0
# xxxxxxx
# Misclassified sample x0
# -------
# -------
# updated weight w = [ 1.   0.1  1.1]
# :) :) :)
# iteration1 on X1
# iteration2 on X2
# xxxxxxx
# Misclassified sample x2
# -------
# -------
# updated weight w = [ 2.  -3.4 -3. ]
# :) :) :)
# iteration3 on X3
# xxxxxxx
# Misclassified sample x3
# -------
# -------
# updated weight w = [ 3.  -1.4 -0.3]
# :) :) :)
# iteration4 on X4
# xxxxxxx
# Misclassified sample x4
# -------
# -------
# updated weight w = [ 4.   2.7  2.5]
# :) :) :)
# iteration5 on X5
# iteration6 on X6
# xxxxxxx
# Misclassified sample x6
# -------
# -------
# updated weight w = [ 5.   1.9  1.2]
# :) :) :)
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [ 4.  -5.2 -3. ]
# :) :) :)
# iteration11 on X11
# xxxxxxx
# Misclassified sample x11
# -------
# -------
# updated weight w = [ 3.  -3.8  1.3]
# :) :) :)
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 3.  -3.8  1.3] at iteration 0
#
# *************************
# Epoch 1
# *************************
#
# current weights [ 3.  -3.8  1.3]
#
# iteration0 on X0
# iteration1 on X1
# xxxxxxx
# Misclassified sample x1
# -------
# -------
# updated weight w = [ 4.   3.   8.4]
# :) :) :)
# iteration2 on X2
# xxxxxxx
# Misclassified sample x2
# -------
# -------
# updated weight w = [ 5.  -0.5  4.3]
# :) :) :)
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# xxxxxxx
# Misclassified sample x6
# -------
# -------
# updated weight w = [ 6.  -1.3  3. ]
# :) :) :)
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [ 5.  -8.4 -1.2]
# :) :) :)
# iteration11 on X11
# xxxxxxx
# Misclassified sample x11
# -------
# -------
# updated weight w = [ 4.  -7.   3.1]
# :) :) :)
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 4.  -7.   3.1] at iteration 1
#
# *************************
# Epoch 2
# *************************
#
# current weights [ 4.  -7.   3.1]
#
# iteration0 on X0
# iteration1 on X1
# xxxxxxx
# Misclassified sample x1
# -------
# -------
# updated weight w = [  5.   -0.2  10.2]
# :) :) :)
# iteration2 on X2
# xxxxxxx
# Misclassified sample x2
# -------
# -------
# updated weight w = [ 6.  -3.7  6.1]
# :) :) :)
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [  5.  -10.8   1.9]
# :) :) :)
# iteration11 on X11
# xxxxxxx
# Misclassified sample x11
# -------
# -------
# updated weight w = [ 4.  -9.4  6.2]
# :) :) :)
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 4.  -9.4  6.2] at iteration 2
#
# *************************
# Epoch 3
# *************************
#
# current weights [ 4.  -9.4  6.2]
#
# iteration0 on X0
# iteration1 on X1
# xxxxxxx
# Misclassified sample x1
# -------
# -------
# updated weight w = [  5.   -2.6  13.3]
# :) :) :)
# iteration2 on X2
# xxxxxxx
# Misclassified sample x2
# -------
# -------
# updated weight w = [ 6.  -6.1  9.2]
# :) :) :)
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# xxxxxxx
# Misclassified sample x6
# -------
# -------
# updated weight w = [ 7.  -6.9  7.9]
# :) :) :)
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 7.  -6.9  7.9] at iteration 3
#
# *************************
# Epoch 4
# *************************
#
# current weights [ 7.  -6.9  7.9]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# xxxxxxx
# Misclassified sample x2
# -------
# -------
# updated weight w = [  8.  -10.4   3.8]
# :) :) :)
# iteration3 on X3
# xxxxxxx
# Misclassified sample x3
# -------
# -------
# updated weight w = [ 9.  -8.4  6.5]
# :) :) :)
# iteration4 on X4
# xxxxxxx
# Misclassified sample x4
# -------
# -------
# updated weight w = [ 10.   -4.3   9.3]
# :) :) :)
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [  9.  -11.4   5.1]
# :) :) :)
# iteration11 on X11
# xxxxxxx
# Misclassified sample x11
# -------
# -------
# updated weight w = [  8.  -10.    9.4]
# :) :) :)
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [  8.  -10.    9.4] at iteration 4
#
# *************************
# Epoch 5
# *************************
#
# current weights [  8.  -10.    9.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# xxxxxxx
# Misclassified sample x4
# -------
# -------
# updated weight w = [  9.   -5.9  12.2]
# :) :) :)
# iteration5 on X5
# iteration6 on X6
# xxxxxxx
# Misclassified sample x6
# -------
# -------
# updated weight w = [ 10.   -6.7  10.9]
# :) :) :)
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [  9.  -13.8   6.7]
# :) :) :)
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [  9.  -13.8   6.7] at iteration 5
#
# *************************
# Epoch 6
# *************************
#
# current weights [  9.  -13.8   6.7]
#
# iteration0 on X0
# iteration1 on X1
# xxxxxxx
# Misclassified sample x1
# -------
# -------
# updated weight w = [ 10.   -7.   13.8]
# :) :) :)
# iteration2 on X2
# xxxxxxx
# Misclassified sample x2
# -------
# -------
# updated weight w = [ 11.  -10.5   9.7]
# :) :) :)
# iteration3 on X3
# iteration4 on X4
# xxxxxxx
# Misclassified sample x4
# -------
# -------
# updated weight w = [ 12.   -6.4  12.5]
# :) :) :)
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [ 11.  -13.5   8.3]
# :) :) :)
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 11.  -13.5   8.3] at iteration 6
#
# *************************
# Epoch 7
# *************************
#
# current weights [ 11.  -13.5   8.3]
#
# iteration0 on X0
# iteration1 on X1
# xxxxxxx
# Misclassified sample x1
# -------
# -------
# updated weight w = [ 12.   -6.7  15.4]
# :) :) :)
# iteration2 on X2
# xxxxxxx
# Misclassified sample x2
# -------
# -------
# updated weight w = [ 13.  -10.2  11.3]
# :) :) :)
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 7
#
# *************************
# Epoch 8
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 8
#
# *************************
# Epoch 9
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 9
#
# *************************
# Epoch 10
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 10
#
# *************************
# Epoch 11
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 11
#
# *************************
# Epoch 12
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 12
#
# *************************
# Epoch 13
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 13
#
# *************************
# Epoch 14
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 14
#
# *************************
# Epoch 15
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 15
#
# *************************
# Epoch 16
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 16
#
# *************************
# Epoch 17
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 17
#
# *************************
# Epoch 18
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 18
#
# *************************
# Epoch 19
# *************************
#
# current weights [ 13.  -10.2  11.3]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 13.  -10.2  11.3] at iteration 19
#
# [ 13.  -10.2  11.3]

# %% [markdown]
# #### Note: At Iteration 7, the algorithm find the solution vector as w = [ 13.  -10.2  11.3]

# %% [markdown]
# ### Linear Classfier that discrimnate the two classes C1, C2 using the above solution vector

# %%
plot_classifier(x11,x21,x12,x22,w1)

# %% [markdown]
# ### 2. Use the data given in Table 1. Run the same algorithm for building a classifier to separate C 2 and C 3 .

# %% [markdown]
# plot the data points for C2 and C3

# %%
plt.figure(2)
s=20
plt.scatter(x12,x22,color='g', s=2*s, marker='^', alpha=.8, label='C2')
plt.scatter(x13,x23,color='r', s=2*s, marker='o', alpha=.8, label='C3')
plt.title("Class2 vs. Class3")
plt.xlabel("x1")
plt.ylabel("x2")
plt.axis("tight")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Plot the final classifier. Note the number of iterations required for
# convergence.

# %%
X2 = np.c_[np.ones(x12.shape), x12, x22]
X3 = np.c_[np.ones(x13.shape), x13, x23]
X23 = np.r_[X2,-X3]
w = np.array([0,0,0])

# %%
w2 = percp(X23,w.T,20)
# Out:
# *************************
# Epoch 0
# *************************
#
# current weights [0 0 0]
#
# iteration0 on X0
# xxxxxxx
# Misclassified sample x0
# -------
# -------
# updated weight w = [ 1.   7.1  4.2]
# :) :) :)
# iteration1 on X1
# xxxxxxx
# Misclassified sample x1
# -------
# -------
# updated weight w = [ 2.   5.7 -0.1]
# :) :) :)
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# xxxxxxx
# Misclassified sample x11
# -------
# -------
# updated weight w = [ 1.   5.2 -8.8]
# :) :) :)
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [ 1.   5.2 -8.8] at iteration 0
#
# *************************
# Epoch 1
# *************************
#
# current weights [ 1.   5.2 -8.8]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [ 0.   8.2 -5.9]
# :) :) :)
# iteration11 on X11
# iteration12 on X12
# xxxxxxx
# Misclassified sample x12
# -------
# -------
# updated weight w = [-1.   5.3 -8. ]
# :) :) :)
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-1.   5.3 -8. ] at iteration 1
#
# *************************
# Epoch 2
# *************************
#
# current weights [-1.   5.3 -8. ]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [-2.   8.3 -5.1]
# :) :) :)
# iteration11 on X11
# iteration12 on X12
# xxxxxxx
# Misclassified sample x12
# -------
# -------
# updated weight w = [-3.   5.4 -7.2]
# :) :) :)
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-3.   5.4 -7.2] at iteration 2
#
# *************************
# Epoch 3
# *************************
#
# current weights [-3.   5.4 -7.2]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# xxxxxxx
# Misclassified sample x10
# -------
# -------
# updated weight w = [-4.   8.4 -4.3]
# :) :) :)
# iteration11 on X11
# iteration12 on X12
# xxxxxxx
# Misclassified sample x12
# -------
# -------
# updated weight w = [-5.   5.5 -6.4]
# :) :) :)
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 3
#
# *************************
# Epoch 4
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 4
#
# *************************
# Epoch 5
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 5
#
# *************************
# Epoch 6
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 6
#
# *************************
# Epoch 7
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 7
#
# *************************
# Epoch 8
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 8
#
# *************************
# Epoch 9
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 9
#
# *************************
# Epoch 10
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 10
#
# *************************
# Epoch 11
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 11
#
# *************************
# Epoch 12
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 12
#
# *************************
# Epoch 13
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 13
#
# *************************
# Epoch 14
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 14
#
# *************************
# Epoch 15
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 15
#
# *************************
# Epoch 16
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 16
#
# *************************
# Epoch 17
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 17
#
# *************************
# Epoch 18
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 18
#
# *************************
# Epoch 19
# *************************
#
# current weights [-5.   5.5 -6.4]
#
# iteration0 on X0
# iteration1 on X1
# iteration2 on X2
# iteration3 on X3
# iteration4 on X4
# iteration5 on X5
# iteration6 on X6
# iteration7 on X7
# iteration8 on X8
# iteration9 on X9
# iteration10 on X10
# iteration11 on X11
# iteration12 on X12
# iteration13 on X13
# iteration14 on X14
# iteration15 on X15
# iteration16 on X16
# iteration17 on X17
# iteration18 on X18
# iteration19 on X19
#
# Finally the best weight vector is [-5.   5.5 -6.4] at iteration 19
#
# [-5.   5.5 -6.4]

# %% [markdown]
# #### Note: At Iteration 4, the algorithm find the solution vector as w = [-5.   5.5 -6.4]

# %% [markdown]
# ### Linear Classfier that discrimnate the two classes C1, C2 using the above solution vector

# %%
plot_classifier(x12,x22,x13,x23,w2)

# %% [markdown]
# #### 3. Comment on the difference on the number of iteration required for convergence in above two cases and give reasons.

# %%
plt.figure(figsize=(10,6))
plt.subplot(211)
plt.scatter(x11,x21,color='r', s=2*s, marker='^', alpha=.8, label='C1')
plt.scatter(x12,x22,color='g', s=2*s, marker='o', alpha=.8, label='C2')
plt.legend(loc="upper left")
plt.title("figure.a")
plt.xlabel("x1")
plt.ylabel("x2")
plt.subplot(212)
plt.scatter(x12,x22,color='g', s=2*s, marker='^', alpha=.8, label='C2')
plt.scatter(x13,x23,color='b', s=2*s, marker='o', alpha=.8, label='C3')
plt.legend(loc="lower right")
plt.title("figure.b")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %% [markdown]
# ###### From the figure above, the features of C1, C2  ( figure.a ) are closely coupled as compared to the features of C2,C3 (figure.b).
#
# Hence finding the optimally best solution vector for (C1,C2) takes more number of iterations thatn finding an optimally best solution for (C2,C3), 7, 4 number of iterations respectively.
